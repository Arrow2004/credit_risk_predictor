# %%
import gdown
url = "https://drive.google.com/uc?id=1a2Hsbf0k1fSbKAYYVp00YF3i_OtWE31j"  # convert sharing link to direct download
output = "merged_data.csv"
gdown.download(url, output, quiet=False)

import pandas as pd
data = pd.read_csv(output)

data.head()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a2Hsbf0k1fSbKAYYVp00YF3i_OtWE31j
# To: /content/merged_data.csv
# 100%|██████████| 31.2M/31.2M [00:00<00:00, 64.8MB/s]
#     c_id  application_hour  application_day_of_week  account_open_year  \
# 0  10000                 5                        6               2013
# 1  10001                 4                        2               2015
# 2  10002                10                        3               2020
# 3  10003                 7                        5               2010
# 4  10004                 1                        2               2020
#
#   preferred_contact  num_login_sessions  num_customer_service_calls  \
# 0              Mail                  13                           2
# 1             Phone                   6                           1
# 2             Phone                   1                           2
# 3             Email                   4                           1
# 4              Mail                   6                           2
#
#    has_mobile_app  paperless_billing  default  ... employment_type  \
# 0               1                  1        0  ...       Full-time
# 1               1                  1        1  ...       FULL_TIME
# 2               1                  0        0  ...       FULL_TIME
# 3               1                  1        0  ...       Full Time
# 4               1                  0        0  ...        Fulltime
#
#      education marital_status  num_dependents  credit_score  \
# 0     Graduate        Married               2           696
# 1  High School        Married               0           659
# 2     Bachelor         Single               0           662
# 3     Bachelor         Single               0           676
# 4  High School         Single               0           678
#
#    num_credit_accounts  oldest_credit_line_age oldest_account_age_months  \
# 0                   14                    22.8                     273.6
# 1                   13                     3.5                      42.0
# 2                    3                     0.0                       0.0
# 3                    8                     9.0                     108.0
# 4                    7                     8.0                      96.0
#
#   total_credit_limit account_diversity_index
# 0             169100                   0.499
# 1              78200                   0.298
# 2              41400                   0.174
# 3              60000                   0.263
# 4              49700                   0.298
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Missing Values Check

# %% [markdown]
# ### Checking

# %%
import pandas as pd

missing_counts = data.isnull().sum()
missing_percent = (missing_counts / len(data)) * 100

missing_df = pd.DataFrame({'MissingCount': missing_counts,
    'MissingPercent': missing_percent}).sort_values(by='MissingCount', ascending=False)

print(missing_df)
# Out:
#                             MissingCount  MissingPercent
# employment_length                   2253        2.503361
# revolving_balance                   1377        1.530017
# application_hour                       0        0.000000
# application_day_of_week                0        0.000000
# preferred_contact                      0        0.000000
# account_open_year                      0        0.000000
# num_customer_service_calls             0        0.000000
# has_mobile_app                         0        0.000000
# paperless_billing                      0        0.000000
# num_login_sessions                     0        0.000000
# default                                0        0.000000
# monthly_income                         0        0.000000
# monthly_payment                        0        0.000000
# existing_monthly_debt                  0        0.000000
# debt_to_income_ratio                   0        0.000000
# debt_service_ratio                     0        0.000000
# payment_to_income_ratio                0        0.000000
# c_id                                   0        0.000000
# credit_utilization                     0        0.000000
# credit_usage_amount                    0        0.000000
# total_monthly_debt_payment             0        0.000000
# available_credit                       0        0.000000
# loan_to_annual_income                  0        0.000000
# total_debt_amount                      0        0.000000
# monthly_free_cash_flow                 0        0.000000
# annual_debt_payment                    0        0.000000
# regional_median_income                 0        0.000000
# regional_median_rent                   0        0.000000
# housing_price_index                    0        0.000000
# cost_of_living_index                   0        0.000000
# loan_type                              0        0.000000
# loan_amount                            0        0.000000
# loan_term                              0        0.000000
# regional_unemployment_rate             0        0.000000
# interest_rate                          0        0.000000
# loan_purpose                           0        0.000000
# origination_channel                    0        0.000000
# loan_to_value_ratio                    0        0.000000
# age                                    0        0.000000
# annual_income                          0        0.000000
# employment_type                        0        0.000000
# education                              0        0.000000
# marital_status                         0        0.000000
# num_dependents                         0        0.000000
# credit_score                           0        0.000000
# num_credit_accounts                    0        0.000000
# oldest_credit_line_age                 0        0.000000
# oldest_account_age_months              0        0.000000
# total_credit_limit                     0        0.000000
# account_diversity_index                0        0.000000

# %% [markdown]
# We can see that there are missing values in employment_length and revolving_balance

# %%
data['revolving_balance'] = data['revolving_balance'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-2299545015.py:1: SyntaxWarning: invalid escape sequence '\$'
#   data['revolving_balance'] = data['revolving_balance'].replace('[\$,]', '', regex=True).astype(float)

# %% [markdown]
# ### Imputing

# %%
cols = ['employment_length', 'revolving_balance']

for col in cols:
  mean_val = data[col].mean()
  median_val = data[col].median()
  mode_val = data[col].mode()[0]  # mode() returns a Series

  print(f"{col}:")
  print(f"  Mean   = {mean_val}")
  print(f"  Median = {median_val}")
  print(f"  Mode   = {mode_val}\n")
# Out:
# employment_length:
#   Mean   = 5.514892986574887
#   Median = 5.2
#   Mode   = 4.9
#
# revolving_balance:
#   Mean   = 39561.29588364063
#   Median = 29294.7
#   Mode   = 18468.0

# %% [markdown]
# Median is a robust choice for both

# %%
from sklearn.impute import SimpleImputer

emp_imputer = SimpleImputer(strategy='median')
data[['employment_length']] = emp_imputer.fit_transform(data[['employment_length']])

rev_imputer = SimpleImputer(strategy='median')
data[['revolving_balance']] = rev_imputer.fit_transform(data[['revolving_balance']])

# %% [markdown]
# ### Type Conversion where needed

# %%
print(data.dtypes)
# Out:
# c_id                            int64
# application_hour                int64
# application_day_of_week         int64
# account_open_year               int64
# preferred_contact              object
# num_login_sessions              int64
# num_customer_service_calls      int64
# has_mobile_app                  int64
# paperless_billing               int64
# default                         int64
# monthly_income                 object
# existing_monthly_debt          object
# monthly_payment                object
# debt_to_income_ratio          float64
# debt_service_ratio            float64
# payment_to_income_ratio       float64
# credit_utilization            float64
# revolving_balance             float64
# credit_usage_amount            object
# available_credit               object
# total_monthly_debt_payment     object
# annual_debt_payment           float64
# loan_to_annual_income         float64
# total_debt_amount              object
# monthly_free_cash_flow         object
# regional_unemployment_rate    float64
# regional_median_income          int64
# regional_median_rent          float64
# housing_price_index           float64
# cost_of_living_index          float64
# loan_type                      object
# loan_amount                    object
# loan_term                       int64
# interest_rate                 float64
# loan_purpose                   object
# loan_to_value_ratio           float64
# origination_channel            object
# age                             int64
# annual_income                  object
# employment_length             float64
# employment_type                object
# education                      object
# marital_status                 object
# num_dependents                  int64
# credit_score                    int64
# num_credit_accounts             int64
# oldest_credit_line_age        float64
# oldest_account_age_months     float64
# total_credit_limit              int64
# account_diversity_index       float64
# dtype: object

# %%
# Convert numeric columns stored as objects to float
numeric_obj_cols = [
    'monthly_income', 'existing_monthly_debt', 'monthly_payment', 'credit_usage_amount',
        'available_credit', 'total_monthly_debt_payment', 'total_debt_amount',
            'monthly_free_cash_flow', 'loan_amount', 'annual_income']

for col in numeric_obj_cols:
  data[col] = data[col].replace('[\$,]', '', regex=True).astype(float)

categorical_cols = ['preferred_contact', 'loan_type', 'loan_purpose', 'origination_channel',
                            'employment_type', 'education', 'marital_status']

for col in categorical_cols:
  data[col] = data[col].astype('category')

print(data.dtypes)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\$'
# <>:8: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-737979403.py:8: SyntaxWarning: invalid escape sequence '\$'
#   data[col] = data[col].replace('[\$,]', '', regex=True).astype(float)
# c_id                             int64
# application_hour                 int64
# application_day_of_week          int64
# account_open_year                int64
# preferred_contact             category
# num_login_sessions               int64
# num_customer_service_calls       int64
# has_mobile_app                   int64
# paperless_billing                int64
# default                          int64
# monthly_income                 float64
# existing_monthly_debt          float64
# monthly_payment                float64
# debt_to_income_ratio           float64
# debt_service_ratio             float64
# payment_to_income_ratio        float64
# credit_utilization             float64
# revolving_balance              float64
# credit_usage_amount            float64
# available_credit               float64
# total_monthly_debt_payment     float64
# annual_debt_payment            float64
# loan_to_annual_income          float64
# total_debt_amount              float64
# monthly_free_cash_flow         float64
# regional_unemployment_rate     float64
# regional_median_income           int64
# regional_median_rent           float64
# housing_price_index            float64
# cost_of_living_index           float64
# loan_type                     category
# loan_amount                    float64
# loan_term                        int64
# interest_rate                  float64
# loan_purpose                  category
# loan_to_value_ratio            float64
# origination_channel           category
# age                              int64
# annual_income                  float64
# employment_length              float64
# employment_type               category
# education                     category
# marital_status                category
# num_dependents                   int64
# credit_score                     int64
# num_credit_accounts              int64
# oldest_credit_line_age         float64
# oldest_account_age_months      float64
# total_credit_limit               int64
# account_diversity_index        float64
# dtype: object

# %% [markdown]
# ### Encoding Categorical Features

# %%
categorical_cols = data.select_dtypes(include='category').columns.tolist()
print(categorical_cols)
# Out:
# ['preferred_contact', 'loan_type', 'loan_purpose', 'origination_channel', 'employment_type', 'education', 'marital_status']

# %%
data['loan_type_original'] = data['loan_type'].copy()
data['employment_type_original'] = data['employment_type'].copy()

# %%
data['loan_type_clean'] = data['loan_type'].str.strip().str.lower()
data['employment_type_clean'] = data['employment_type'].str.strip().str.lower()

# %%
loan_type_map = {
      'personal': 'Personal',
          'personal loan': 'Personal',
              'personalloan': 'Personal',
                  'cc': 'Credit Card',
                      'credit card': 'Credit Card',
                          'creditcard': 'Credit Card',
                              'mortgage': 'Mortgage',
                                  'mortgage loan': 'Mortgage',
                                      'home loan': 'Home Loan'
                                      }

employment_type_map = {
      'full-time': 'Full-time',
          'full time': 'Full-time',
              'full_time': 'Full-time',
                  'fulltime': 'Full-time',
                      'ft': 'Full-time',
                          'part time': 'Part-time',
                              'part-time': 'Part-time',
                                  'pt': 'Part-time',
                                      'self employed': 'Self-employed',
                                          'self emp': 'Self-employed',
                                              'self-employed': 'Self-employed',
                                                  'self_employed': 'Self-employed',
                                                      'contract': 'Contract',
                                                          'contractor': 'Contract'
                                                          }
data['loan_type'] = data['loan_type_clean'].replace(loan_type_map)
data['employment_type'] = data['employment_type_clean'].replace(employment_type_map)

# Optional: drop temporary clean columns
data.drop(['loan_type_clean', 'employment_type_clean'], axis=1, inplace=True)

# Verify results
print("Loan type categories:", data['loan_type'].unique())
print("Employment type categories:", data['employment_type'].unique())
print("Missing values in loan_type:", data['loan_type'].isnull().sum())
print("Missing values in employment_type:", data['employment_type'].isnull().sum())
# Out:
# Loan type categories: ['Personal' 'Mortgage' 'Credit Card' 'Home Loan']
# Employment type categories: ['Full-time' 'Part-time' 'Self-employed' 'Contract' 'part_time']
# Missing values in loan_type: 0
# Missing values in employment_type: 0

# %%
categorical_cols = ['loan_type', 'employment_type', 'preferred_contact',
                    'loan_purpose', 'origination_channel', 'education', 'marital_status']

for col in categorical_cols:
  uniques = data[col].dropna().unique()  # dropna to ignore missing values
  print(f"{col} unique values ({len(uniques)}): {uniques}\n")
# Out:
# loan_type unique values (4): ['Personal' 'Mortgage' 'Credit Card' 'Home Loan']
#
# employment_type unique values (5): ['Full-time' 'Part-time' 'Self-employed' 'Contract' 'part_time']
#
# preferred_contact unique values (3): ['Mail', 'Phone', 'Email']
# Categories (3, object): ['Email', 'Mail', 'Phone']
#
# loan_purpose unique values (8): ['Debt Consolidation', 'Refinance', 'Major Purchase', 'Medical', 'Revolving Credit', 'Home Improvement', 'Home Purchase', 'Other']
# Categories (8, object): ['Debt Consolidation', 'Home Improvement', 'Home Purchase', 'Major Purchase',
#                          'Medical', 'Other', 'Refinance', 'Revolving Credit']
#
# origination_channel unique values (4): ['Direct Mail', 'Branch', 'Online', 'Broker']
# Categories (4, object): ['Branch', 'Broker', 'Direct Mail', 'Online']
#
# education unique values (5): ['Graduate', 'High School', 'Bachelor', 'Some College', 'Advanced']
# Categories (5, object): ['Advanced', 'Bachelor', 'Graduate', 'High School', 'Some College']
#
# marital_status unique values (3): ['Married', 'Single', 'Divorced']
# Categories (3, object): ['Divorced', 'Married', 'Single']

# %%
data['employment_type'] = data['employment_type'].replace({'part_time': 'Part-time'})

# %%
print(data['employment_type'].unique())
# Out:
# ['Full-time' 'Part-time' 'Self-employed' 'Contract']

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

ordinal_cols = ['education']  # Columns with natural order
nominal_cols = ['loan_type', 'employment_type', 'loan_purpose',
                'preferred_contact', 'origination_channel', 'marital_status']

education_order = ["High School", "Some College", "Bachelor", "Graduate", "Advanced"]
data['education'] = pd.Categorical(data['education'], categories=education_order, ordered=True)
data['education_encoded'] = data['education'].cat.codes

data = pd.get_dummies(data, columns=nominal_cols, drop_first=True)

print("Encoded columns sample:")
print(data.head())
print("\nAll columns:")
print(data.columns)
# Out:
# Encoded columns sample:
#     c_id  application_hour  application_day_of_week  account_open_year  \
# 0  10000                 5                        6               2013
# 1  10001                 4                        2               2015
# 2  10002                10                        3               2020
# 3  10003                 7                        5               2010
# 4  10004                 1                        2               2020
#
#    num_login_sessions  num_customer_service_calls  has_mobile_app  \
# 0                  13                           2               1
# 1                   6                           1               1
# 2                   1                           2               1
# 3                   4                           1               1
# 4                   6                           2               1
#
#    paperless_billing  default  monthly_income  ...  loan_purpose_Other  \
# 0                  1        0         5150.00  ...               False
# 1                  1        1         2383.33  ...               False
# 2                  0        0         1725.00  ...               False
# 3                  1        0         2616.67  ...               False
# 4                  0        0         2050.00  ...               False
#
#    loan_purpose_Refinance  loan_purpose_Revolving Credit  \
# 0                   False                          False
# 1                    True                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
#
#    preferred_contact_Mail  preferred_contact_Phone  \
# 0                    True                    False
# 1                   False                     True
# 2                   False                     True
# 3                   False                    False
# 4                    True                    False
#
#    origination_channel_Broker  origination_channel_Direct Mail  \
# 0                       False                             True
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                            False
#
#    origination_channel_Online  marital_status_Married  marital_status_Single
# 0                       False                    True                  False
# 1                       False                    True                  False
# 2                        True                   False                   True
# 3                        True                   False                   True
# 4                       False                   False                   True
#
# [5 rows x 67 columns]
#
# All columns:
# Index(['c_id', 'application_hour', 'application_day_of_week',
#        'account_open_year', 'num_login_sessions', 'num_customer_service_calls',
#        'has_mobile_app', 'paperless_billing', 'default', 'monthly_income',
#        'existing_monthly_debt', 'monthly_payment', 'debt_to_income_ratio',
#        'debt_service_ratio', 'payment_to_income_ratio', 'credit_utilization',
#        'revolving_balance', 'credit_usage_amount', 'available_credit',
#        'total_monthly_debt_payment', 'annual_debt_payment',
#        'loan_to_annual_income', 'total_debt_amount', 'monthly_free_cash_flow',
#        'regional_unemployment_rate', 'regional_median_income',
#        'regional_median_rent', 'housing_price_index', 'cost_of_living_index',
#        'loan_amount', 'loan_term', 'interest_rate', 'loan_to_value_ratio',
#        'age', 'annual_income', 'employment_length', 'education',
#        'num_dependents', 'credit_score', 'num_credit_accounts',
#        'oldest_credit_line_age', 'oldest_account_age_months',
#        'total_credit_limit', 'account_diversity_index', 'loan_type_original',
#        'employment_type_original', 'education_encoded', 'loan_type_Home Loan',
#        'loan_type_Mortgage', 'loan_type_Personal', 'employment_type_Full-time',
#        'employment_type_Part-time', 'employment_type_Self-employed',
#        'loan_purpose_Home Improvement', 'loan_purpose_Home Purchase',
#        'loan_purpose_Major Purchase', 'loan_purpose_Medical',
#        'loan_purpose_Other', 'loan_purpose_Refinance',
#        'loan_purpose_Revolving Credit', 'preferred_contact_Mail',
#        'preferred_contact_Phone', 'origination_channel_Broker',
#        'origination_channel_Direct Mail', 'origination_channel_Online',
#        'marital_status_Married', 'marital_status_Single'],
#       dtype='object')

# %%
cols_to_drop = ['loan_type_original', 'employment_type_original', 'education']
data.drop(columns=cols_to_drop, inplace=True)

# %%
print(data.dtypes)
# Out:
# c_id                               int64
# application_hour                   int64
# application_day_of_week            int64
# account_open_year                  int64
# num_login_sessions                 int64
#                                    ...
# origination_channel_Broker          bool
# origination_channel_Direct Mail     bool
# origination_channel_Online          bool
# marital_status_Married              bool
# marital_status_Single               bool
# Length: 64, dtype: object

# %% [markdown]
# ## Scaling and transformations

# %%
continuous_cols = [ 'monthly_income', 'existing_monthly_debt', 'monthly_payment',
                   'debt_to_income_ratio', 'revolving_balance', 'credit_usage_amount',
                    'available_credit', 'total_monthly_debt_payment', 'annual_debt_payment',
                     'loan_to_annual_income', 'total_debt_amount', 'monthly_free_cash_flow',
                     'loan_amount', 'interest_rate', 'loan_to_value_ratio', 'age',
                    'annual_income', 'employment_length', 'num_dependents', 'credit_score',
                    'num_credit_accounts', 'oldest_credit_line_age', 'oldest_account_age_months',
                    'total_credit_limit', 'account_diversity_index']
print(data[continuous_cols].describe())
pd.set_option('display.max_rows', None)      # Show all rows
pd.set_option('display.max_columns', None)   # Show all columns
pd.set_option('display.max_colwidth', None)  # Full string width
print(data[continuous_cols].skew().sort_values(ascending=False))
# Out:
#        monthly_income  existing_monthly_debt  monthly_payment  \
# count    89999.000000           89999.000000     89999.000000
# mean      3965.571882             894.136941       927.723597
# std       2224.252044             679.000900       892.264464
# min       1666.670000              83.360000        15.000000
# 25%       2341.670000             424.475000       294.000000
# 50%       3425.000000             706.150000       565.940000
# 75%       4941.670000            1168.840000      1325.955000
# max      40600.000000            9229.850000      7542.690000
#
#        debt_to_income_ratio  revolving_balance  credit_usage_amount  \
# count          89999.000000       89999.000000         89999.000000
# mean               0.531225       39404.215221         39557.125978
# std                0.379553       34522.296287         34753.792901
# min                0.054000         804.300000           804.300000
# 25%                0.296000       16731.600000         16549.900000
# 50%                0.424000       29294.700000         29280.400000
# 75%                0.628000       50465.400000         50936.600000
# max                4.630000      442616.200000        442616.200000
#
#        available_credit  total_monthly_debt_payment  annual_debt_payment  \
# count      89999.000000                89999.000000         89999.000000
# mean       51926.298282                 1821.860538         21862.326456
# std        45396.043541                 1105.875526         13270.506317
# min            0.000000                  111.130000          1333.560000
# 25%        21960.400000                  980.240000         11762.880000
# 50%        38648.400000                 1554.610000         18655.320000
# 75%        66798.400000                 2431.090000         29173.080000
# max       483500.000000                10806.070000        129672.840000
#
#        loan_to_annual_income  total_debt_amount  monthly_free_cash_flow  \
# count           89999.000000       89999.000000            89999.000000
# mean                2.873295      145535.117956             2143.700718
# std                 4.618819      151074.496379             2025.965697
# min                 0.004655        2987.600000            -6050.800000
# 25%                 0.218289       37078.300000              944.000000
# 50%                 0.512500       67975.800000             1845.900000
# 75%                 3.990456      232867.750000             3109.915000
# max                38.127451      954700.000000            29793.930000
#
#          loan_amount  interest_rate  loan_to_value_ratio           age  \
# count   89999.000000   89999.000000         89999.000000  89999.000000
# mean   105977.991978      11.278835             0.273598     38.715041
# std    147111.296259       4.607331             0.378284     10.805176
# min       500.000000       2.500000             0.000000     18.000000
# 25%      9800.000000       6.960000             0.000000     31.000000
# 50%     19200.000000      11.290000             0.000000     38.000000
# 75%    192800.000000      14.820000             0.725000     46.000000
# max    841300.000000      22.800000             0.970000     74.000000
#
#        annual_income  employment_length  num_dependents  credit_score  \
# count   89999.000000       89999.000000    89999.000000  89999.000000
# mean    47586.732075           5.507010        1.199391    716.281681
# std     26691.159740           3.227441        1.136630     46.076985
# min     20000.000000           0.000000        0.000000    534.000000
# 25%     28100.000000           3.000000        0.000000    685.000000
# 50%     41100.000000           5.200000        1.000000    717.000000
# 75%     59300.000000           7.600000        2.000000    748.000000
# max    487200.000000          23.900000        5.000000    850.000000
#
#        num_credit_accounts  oldest_credit_line_age  oldest_account_age_months  \
# count         89999.000000            89999.000000               89999.000000
# mean              9.400016                9.344400                 112.132806
# std               4.769961                5.111351                  61.336214
# min               0.000000                0.000000                   0.000000
# 25%               6.000000                5.400000                  64.800000
# 50%               9.000000                9.000000                 108.000000
# 75%              13.000000               12.900000                 154.800000
# max              31.000000               32.200000                 386.400000
#
#        total_credit_limit  account_diversity_index
# count        89999.000000             89999.000000
# mean         91483.424260                 0.310799
# std          67988.308788                 0.100995
# min          10000.000000                 0.001000
# 25%          45100.000000                 0.240000
# 50%          72300.000000                 0.309000
# 75%         117800.000000                 0.380000
# max         500000.000000                 0.756000
# revolving_balance             2.465120
# credit_usage_amount           2.434482
# available_credit              2.394475
# loan_to_annual_income         2.286518
# debt_to_income_ratio          2.234278
# existing_monthly_debt         2.029012
# total_credit_limit            1.972657
# monthly_income                1.891674
# annual_income                 1.891644
# monthly_payment               1.563672
# loan_amount                   1.422784
# total_debt_amount             1.338406
# monthly_free_cash_flow        1.206067
# total_monthly_debt_payment    1.184084
# annual_debt_payment           1.184084
# num_dependents                0.912082
# loan_to_value_ratio           0.708557
# employment_length             0.546756
# oldest_account_age_months     0.350673
# oldest_credit_line_age        0.350673
# num_credit_accounts           0.323203
# age                           0.287212
# interest_rate                 0.196405
# account_diversity_index       0.104060
# credit_score                 -0.031426
# dtype: float64

# %%
from sklearn.preprocessing import RobustScaler

# List of continuous features
continuous_cols = [ 'monthly_income', 'existing_monthly_debt', 'monthly_payment',
                   'debt_to_income_ratio', 'revolving_balance', 'credit_usage_amount',
                    'available_credit', 'total_monthly_debt_payment', 'annual_debt_payment',
                     'loan_to_annual_income', 'total_debt_amount', 'monthly_free_cash_flow',
                     'loan_amount', 'interest_rate', 'loan_to_value_ratio', 'age',
                      'annual_income', 'employment_length', 'num_dependents', 'credit_score',
                        'num_credit_accounts', 'oldest_credit_line_age', 'oldest_account_age_months',
                     'total_credit_limit', 'account_diversity_index']

scaler = RobustScaler()

# Fit and transform the continuous features
data[continuous_cols] = scaler.fit_transform(data[continuous_cols])

# Verify the scaling
print(data[continuous_cols].describe().T)
# Out:
#                               count      mean       std       min       25%  \
# monthly_income              89999.0  0.207912  0.855482 -0.676281 -0.416665
# existing_monthly_debt       89999.0  0.252547  0.912188 -0.836673 -0.378410
# monthly_payment             89999.0  0.350581  0.864635 -0.533880 -0.263519
# debt_to_income_ratio        89999.0  0.322968  1.143232 -1.114458 -0.385542
# revolving_balance           89999.0  0.299685  1.023374 -0.844565 -0.372419
# credit_usage_amount         89999.0  0.298858  1.010675 -0.828114 -0.370216
# available_credit            89999.0  0.296130  1.012446 -0.861956 -0.372184
# total_monthly_debt_payment  89999.0  0.184203  0.762226 -0.994920 -0.395885
# annual_debt_payment         89999.0  0.184203  0.762226 -0.994920 -0.395885
# loan_to_annual_income       89999.0  0.625846  1.224447 -0.134630 -0.077995
# total_debt_amount           89999.0  0.396136  0.771617 -0.331929 -0.157810
# monthly_free_cash_flow      89999.0  0.137494  0.935386 -3.645896 -0.416406
# loan_amount                 89999.0  0.474197  0.803887 -0.102186 -0.051366
# interest_rate               89999.0 -0.001420  0.586174 -1.118321 -0.550891
# loan_to_value_ratio         89999.0  0.377377  0.521771  0.000000  0.000000
# age                         89999.0  0.047669  0.720345 -1.333333 -0.466667
# annual_income               89999.0  0.207908  0.855486 -0.676282 -0.416667
# employment_length           89999.0  0.066741  0.701618 -1.130435 -0.478261
# num_dependents              89999.0  0.099696  0.568315 -0.500000 -0.500000
# credit_score                89999.0 -0.011402  0.731381 -2.904762 -0.507937
# num_credit_accounts         89999.0  0.057145  0.681423 -1.285714 -0.428571
# oldest_credit_line_age      89999.0  0.045920  0.681513 -1.200000 -0.480000
# oldest_account_age_months   89999.0  0.045920  0.681513 -1.200000 -0.480000
# total_credit_limit          89999.0  0.263871  0.935190 -0.856946 -0.374140
# account_diversity_index     89999.0  0.012849  0.721396 -2.200000 -0.492857
#
#                             50%       75%        max
# monthly_income              0.0  0.583335  14.298077
# existing_monthly_debt       0.0  0.621590  11.450968
# monthly_payment             0.0  0.736481   6.760711
# debt_to_income_ratio        0.0  0.614458  12.668675
# revolving_balance           0.0  0.627581  12.252444
# credit_usage_amount         0.0  0.629784  12.020223
# available_credit            0.0  0.627816   9.921308
# total_monthly_debt_payment  0.0  0.604115   6.376579
# annual_debt_payment         0.0  0.604115   6.376579
# loan_to_annual_income       0.0  0.922005   9.971710
# total_debt_amount           0.0  0.842190   4.528968
# monthly_free_cash_flow      0.0  0.583594  12.903567
# loan_amount                 0.0  0.948634   4.492350
# interest_rate               0.0  0.449109   1.464377
# loan_to_value_ratio         0.0  1.000000   1.337931
# age                         0.0  0.533333   2.400000
# annual_income               0.0  0.583333  14.298077
# employment_length           0.0  0.521739   4.065217
# num_dependents              0.0  0.500000   2.000000
# credit_score                0.0  0.492063   2.111111
# num_credit_accounts         0.0  0.571429   3.142857
# oldest_credit_line_age      0.0  0.520000   3.093333
# oldest_account_age_months   0.0  0.520000   3.093333
# total_credit_limit          0.0  0.625860   5.883081
# account_diversity_index     0.0  0.507143   3.192857

# %%
print(data.head())
print(data.dtypes)
print(data.isnull().sum())
print(len(data.columns))
# Out:
#     c_id  application_hour  application_day_of_week  account_open_year  \
# 0  10000                 5                        6               2013
# 1  10001                 4                        2               2015
# 2  10002                10                        3               2020
# 3  10003                 7                        5               2010
# 4  10004                 1                        2               2020
#
#    num_login_sessions  num_customer_service_calls  has_mobile_app  \
# 0                  13                           2               1
# 1                   6                           1               1
# 2                   1                           2               1
# 3                   4                           1               1
# 4                   6                           2               1
#
#    paperless_billing  default  monthly_income  existing_monthly_debt  \
# 0                  1        0        0.663462               0.043648
# 1                  1        1       -0.400642              -0.421755
# 2                  0        0       -0.653846              -0.674508
# 3                  1        0       -0.310896              -0.560800
# 4                  0        0       -0.528846              -0.614457
#
#    monthly_payment  debt_to_income_ratio  debt_service_ratio  \
# 0         0.025379             -0.500000            0.258402
# 1         0.434050              0.500000            0.589959
# 2        -0.240447             -0.364458            0.302539
# 3        -0.321157             -0.674699            0.199961
# 4        -0.223973             -0.418675            0.284673
#
#    payment_to_income_ratio  credit_utilization  revolving_balance  \
# 0                    0.115               0.841           3.347337
# 1                    0.425               0.971           1.382515
# 2                    0.184               0.539          -0.206917
# 3                    0.090               0.147          -0.606949
# 4                    0.163               0.488          -0.149438
#
#    credit_usage_amount  available_credit  total_monthly_debt_payment  \
# 0             3.284197         -0.262311                   -0.154282
# 1             1.356682         -0.811379                   -0.102381
# 2            -0.202573         -0.436304                   -0.711810
# 3            -0.595009          0.279486                   -0.710880
# 4            -0.146184         -0.294438                   -0.669284
#
#    annual_debt_payment  loan_to_annual_income  total_debt_amount  \
# 0            -0.154282              -0.059937           0.469572
# 1            -0.102381               0.920827           0.622896
# 2            -0.711810              -0.016761          -0.185716
# 3            -0.710880              -0.062412          -0.257704
# 4            -0.669284              -0.058273          -0.186538
#
#    monthly_free_cash_flow  regional_unemployment_rate  regional_median_income  \
# 0                0.911084                         4.8                   56000
# 1               -0.401050                         4.4                   61000
# 2               -0.296771                         3.9                   74000
# 3                0.114287                         5.8                   75000
# 4               -0.175205                         5.8                   78000
#
#    regional_median_rent  housing_price_index  cost_of_living_index  \
# 0                1380.0                 91.0                  73.0
# 1                1510.0                 92.0                  87.0
# 2                1920.0                125.0                 103.0
# 3                1690.0                158.0                 121.0
# 4                1700.0                152.0                 127.0
#
#    loan_amount  loan_term  interest_rate  loan_to_value_ratio       age  \
# 0    -0.008197         36       0.153944             0.000000  0.200000
# 1     0.518033        180      -0.567430             1.067586  0.000000
# 2    -0.054098         36       0.343511             0.000000 -1.333333
# 3    -0.057377         48       0.250636             0.000000 -0.733333
# 4    -0.065574         24      -0.066158             0.000000 -0.800000
#
#    annual_income  employment_length  num_dependents  credit_score  \
# 0       0.663462          -0.652174             0.5     -0.333333
# 1      -0.400641           0.391304            -0.5     -0.920635
# 2      -0.653846          -0.956522            -0.5     -0.873016
# 3      -0.310897          -0.086957            -0.5     -0.650794
# 4      -0.528846           0.000000            -0.5     -0.619048
#
#    num_credit_accounts  oldest_credit_line_age  oldest_account_age_months  \
# 0             0.714286                1.840000                   1.840000
# 1             0.571429               -0.733333                  -0.733333
# 2            -0.857143               -1.200000                  -1.200000
# 3            -0.142857                0.000000                   0.000000
# 4            -0.285714               -0.133333                  -0.133333
#
#    total_credit_limit  account_diversity_index  education_encoded  \
# 0            1.331499                 1.357143                  3
# 1            0.081155                -0.078571                  0
# 2           -0.425034                -0.964286                  2
# 3           -0.169188                -0.328571                  2
# 4           -0.310867                -0.078571                  0
#
#    loan_type_Home Loan  loan_type_Mortgage  loan_type_Personal  \
# 0                False               False                True
# 1                False                True               False
# 2                False               False                True
# 3                False               False                True
# 4                False               False                True
#
#    employment_type_Full-time  employment_type_Part-time  \
# 0                       True                      False
# 1                       True                      False
# 2                       True                      False
# 3                       True                      False
# 4                       True                      False
#
#    employment_type_Self-employed  loan_purpose_Home Improvement  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
#
#    loan_purpose_Home Purchase  loan_purpose_Major Purchase  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                         True
# 3                       False                        False
# 4                       False                        False
#
#    loan_purpose_Medical  loan_purpose_Other  loan_purpose_Refinance  \
# 0                 False               False                   False
# 1                 False               False                    True
# 2                 False               False                   False
# 3                  True               False                   False
# 4                 False               False                   False
#
#    loan_purpose_Revolving Credit  preferred_contact_Mail  \
# 0                          False                    True
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                    True
#
#    preferred_contact_Phone  origination_channel_Broker  \
# 0                    False                       False
# 1                     True                       False
# 2                     True                       False
# 3                    False                       False
# 4                    False                       False
#
#    origination_channel_Direct Mail  origination_channel_Online  \
# 0                             True                       False
# 1                            False                       False
# 2                            False                        True
# 3                            False                        True
# 4                            False                       False
#
#    marital_status_Married  marital_status_Single
# 0                    True                  False
# 1                    True                  False
# 2                   False                   True
# 3                   False                   True
# 4                   False                   True
# c_id                                 int64
# application_hour                     int64
# application_day_of_week              int64
# account_open_year                    int64
# num_login_sessions                   int64
# num_customer_service_calls           int64
# has_mobile_app                       int64
# paperless_billing                    int64
# default                              int64
# monthly_income                     float64
# existing_monthly_debt              float64
# monthly_payment                    float64
# debt_to_income_ratio               float64
# debt_service_ratio                 float64
# payment_to_income_ratio            float64
# credit_utilization                 float64
# revolving_balance                  float64
# credit_usage_amount                float64
# available_credit                   float64
# total_monthly_debt_payment         float64
# annual_debt_payment                float64
# loan_to_annual_income              float64
# total_debt_amount                  float64
# monthly_free_cash_flow             float64
# regional_unemployment_rate         float64
# regional_median_income               int64
# regional_median_rent               float64
# housing_price_index                float64
# cost_of_living_index               float64
# loan_amount                        float64
# loan_term                            int64
# interest_rate                      float64
# loan_to_value_ratio                float64
# age                                float64
# annual_income                      float64
# employment_length                  float64
# num_dependents                     float64
# credit_score                       float64
# num_credit_accounts                float64
# oldest_credit_line_age             float64
# oldest_account_age_months          float64
# total_credit_limit                 float64
# account_diversity_index            float64
# education_encoded                     int8
# loan_type_Home Loan                   bool
# loan_type_Mortgage                    bool
# loan_type_Personal                    bool
# employment_type_Full-time             bool
# employment_type_Part-time             bool
# employment_type_Self-employed         bool
# loan_purpose_Home Improvement         bool
# loan_purpose_Home Purchase            bool
# loan_purpose_Major Purchase           bool
# loan_purpose_Medical                  bool
# loan_purpose_Other                    bool
# loan_purpose_Refinance                bool
# loan_purpose_Revolving Credit         bool
# preferred_contact_Mail                bool
# preferred_contact_Phone               bool
# origination_channel_Broker            bool
# origination_channel_Direct Mail       bool
# origination_channel_Online            bool
# marital_status_Married                bool
# marital_status_Single                 bool
# dtype: object
# c_id                               0
# application_hour                   0
# application_day_of_week            0
# account_open_year                  0
# num_login_sessions                 0
# num_customer_service_calls         0
# has_mobile_app                     0
# paperless_billing                  0
# default                            0
# monthly_income                     0
# existing_monthly_debt              0
# monthly_payment                    0
# debt_to_income_ratio               0
# debt_service_ratio                 0
# payment_to_income_ratio            0
# credit_utilization                 0
# revolving_balance                  0
# credit_usage_amount                0
# available_credit                   0
# total_monthly_debt_payment         0
# annual_debt_payment                0
# loan_to_annual_income              0
# total_debt_amount                  0
# monthly_free_cash_flow             0
# regional_unemployment_rate         0
# regional_median_income             0
# regional_median_rent               0
# housing_price_index                0
# cost_of_living_index               0
# loan_amount                        0
# loan_term                          0
# interest_rate                      0
# loan_to_value_ratio                0
# age                                0
# annual_income                      0
# employment_length                  0
# num_dependents                     0
# credit_score                       0
# num_credit_accounts                0
# oldest_credit_line_age             0
# oldest_account_age_months          0
# total_credit_limit                 0
# account_diversity_index            0
# education_encoded                  0
# loan_type_Home Loan                0
# loan_type_Mortgage                 0
# loan_type_Personal                 0
# employment_type_Full-time          0
# employment_type_Part-time          0
# employment_type_Self-employed      0
# loan_purpose_Home Improvement      0
# loan_purpose_Home Purchase         0
# loan_purpose_Major Purchase        0
# loan_purpose_Medical               0
# loan_purpose_Other                 0
# loan_purpose_Refinance             0
# loan_purpose_Revolving Credit      0
# preferred_contact_Mail             0
# preferred_contact_Phone            0
# origination_channel_Broker         0
# origination_channel_Direct Mail    0
# origination_channel_Online         0
# marital_status_Married             0
# marital_status_Single              0
# dtype: int64
# 64

# %%
data.to_csv("preprocessed_credit_data.csv", index=False)
